# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data-text.csv")
df.head()
# Out:
#                                            Indicator PUBLISH STATES  Year  \
# 0  Total density per million population: Radiothe...      Published  2010
# 1          Cellular subscribers (per 100 population)      Published  2010
# 2                 Cholera - number of reported cases      Published  2011
# 3                  Plague - number of reported cases      Published  2012
# 4          Cellular subscribers (per 100 population)      Published  2011
#
#   WHO region                   Country Display Value  Numeric  Low  High  \
# 0   Americas  United States of America         12.76    12.76  NaN   NaN
# 1   Americas  United States of America            90    90.00  NaN   NaN
# 2   Americas  United States of America         42.00    42.00  NaN   NaN
# 3   Americas  United States of America          1.00     1.00  NaN   NaN
# 4   Americas  United States of America            93    92.72  NaN   NaN
#
#                                             Comments
# ...

# %%
to_drop=['PUBLISH STATES','WHO region']
df.drop(to_drop,inplace=True,axis=1)
df.head()
# Out:
#                                            Indicator  Year  \
# 0  Total density per million population: Radiothe...  2010
# 1          Cellular subscribers (per 100 population)  2010
# 2                 Cholera - number of reported cases  2011
# 3                  Plague - number of reported cases  2012
# 4          Cellular subscribers (per 100 population)  2011
#
#                     Country Display Value  Numeric  Low  High  \
# 0  United States of America         12.76    12.76  NaN   NaN
# 1  United States of America            90    90.00  NaN   NaN
# 2  United States of America         42.00    42.00  NaN   NaN
# 3  United States of America          1.00     1.00  NaN   NaN
# 4  United States of America            93    92.72  NaN   NaN
#
#                                             Comments
# 0  from the DIRA IAEA radiotherapy database (data...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
##Replace all NaN values in the "Numeric" with values from "Display Value"
df['Numeric'].fillna(df['Display Value'],inplace=True)

# %%
##List column names
list(df.columns)
# Out:
# ['Indicator',
#  'Year',
#  'Country',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
df.head(50)
# Out:
#                                             Indicator  Year  \
# 0   Total density per million population: Radiothe...  2010
# 1           Cellular subscribers (per 100 population)  2010
# 2                  Cholera - number of reported cases  2011
# 3                   Plague - number of reported cases  2012
# 4           Cellular subscribers (per 100 population)  2011
# 5                       Population median age (years)  2012
# 6   Antiretroviral therapy coverage among people w...  2012
# 7           Cellular subscribers (per 100 population)  2012
# 8   Total density per million population: Radiothe...  2013
# 9     Deaths due to HIV/AIDS (per 100 000 population)  2012
# 10                          Most recent census (year)  2010
# 11      Gross national income per capita (PPP int. $)  2002
# 12      Gross national income per capita (PPP int. $)  2003
# 13      Gross national income per capita (PPP int. $)  2004
# 14      Gross national income per capita (PPP int. $)  2005
# ...
